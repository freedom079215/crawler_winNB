# %%
import requests

def fetch(url):
    response = requests.get(url)
    response = requests.get(url, cookies={'over18': '1'})  # 一直向 server 回答滿 18 歲了 !
    return response

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
resp = fetch(url)  # step-1

print(resp.text) # result of setp-1
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39174.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467730.A.C2B.html">[問卦] 最近感冒都是咳嗽和拉肚子嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">DragonQuest</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%80%E8%BF%91%E6%84%9F%E5%86%92%E9%83%BD%E6%98%AF%E5%92%B3%E5%97%BD%E5%92%8C%E6%8B%89%E8%82%9A%E5%AD%90%E5%97%8E%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ADragonQuest">搜尋看板內 DragonQuest 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467770.A.507.html">Re: [新聞]川普宣布 美國與墨西哥就新貿易協定達協議</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">hugh509</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D%E5%B7%9D%E6%99%AE%E5%AE%A3%E5%B8%83&#43;%E7%BE%8E%E5%9C%8B%E8%88%87%E5%A2%A8%E8%A5%BF%E5%93%A5%E5%B0%B1%E6%96%B0%E8%B2%BF%E6%98%93%E5%8D%94%E5%AE%9A%E9%81%94%E5%8D%94%E8%AD%B0">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ahugh509">搜尋看板內 hugh509 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467774.A.CC7.html">[新聞] 【真愛動畫】差35歲姊弟戀　開心籌備盛大</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ymuit</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E3%80%90%E7%9C%9F%E6%84%9B%E5%8B%95%E7%95%AB%E3%80%91%E5%B7%AE35%E6%AD%B2%E5%A7%8A%E5%BC%9F%E6%88%80%E3%80%80%E9%96%8B%E5%BF%83%E7%B1%8C%E5%82%99%E7%9B%9B%E5%A4%A7">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aymuit">搜尋看板內 ymuit 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467817.A.962.html">Re: [問卦] 學弟最近失戀 該怎麼安慰他 :)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">cosmite</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%AD%B8%E5%BC%9F%E6%9C%80%E8%BF%91%E5%A4%B1%E6%88%80&#43;%E8%A9%B2%E6%80%8E%E9%BA%BC%E5%AE%89%E6%85%B0%E4%BB%96&#43;%3A%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Acosmite">搜尋看板內 cosmite 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467820.A.A2C.html">[問卦] 吳奕凡一直說自己來自中國是??</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">gk524</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%90%B3%E5%A5%95%E5%87%A1%E4%B8%80%E7%9B%B4%E8%AA%AA%E8%87%AA%E5%B7%B1%E4%BE%86%E8%87%AA%E4%B8%AD%E5%9C%8B%E6%98%AF%3F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Agk524">搜尋看板內 gk524 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467821.A.A03.html">[新聞] 日本川崎原女大生騎電動自行車邊玩手機撞死人被判刑</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">chart</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E6%97%A5%E6%9C%AC%E5%B7%9D%E5%B4%8E%E5%8E%9F%E5%A5%B3%E5%A4%A7%E7%94%9F%E9%A8%8E%E9%9B%BB%E5%8B%95%E8%87%AA%E8%A1%8C%E8%BB%8A%E9%82%8A%E7%8E%A9%E6%89%8B%E6%A9%9F%E6%92%9E%E6%AD%BB%E4%BA%BA%E8%A2%AB%E5%88%A4%E5%88%91">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Achart">搜尋看板內 chart 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467830.A.48B.html">[問卦] 有個女的要我跟他一起找金毛鈴</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Changyaya</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%89%E5%80%8B%E5%A5%B3%E7%9A%84%E8%A6%81%E6%88%91%E8%B7%9F%E4%BB%96%E4%B8%80%E8%B5%B7%E6%89%BE%E9%87%91%E6%AF%9B%E9%88%B4">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AChangyaya">搜尋看板內 Changyaya 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467849.A.54F.html">[問卦] 真的有鄉民遇到&#34;送肉粽&#34;跟著的嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">PasManquer</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%9C%9F%E7%9A%84%E6%9C%89%E9%84%89%E6%B0%91%E9%81%87%E5%88%B0%22%E9%80%81%E8%82%89%E7%B2%BD%22%E8%B7%9F%E8%91%97%E7%9A%84%E5%97%8E%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3APasManquer">搜尋看板內 PasManquer 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467864.A.995.html">[問卦] 有人會用鯉魚嘴尻槍嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">thegreatlcx</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%89%E4%BA%BA%E6%9C%83%E7%94%A8%E9%AF%89%E9%AD%9A%E5%98%B4%E5%B0%BB%E6%A7%8D%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Athegreatlcx">搜尋看板內 thegreatlcx 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467865.A.5A5.html">[新聞] 「東奧正名」許維智：如果台灣人沒替自己</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">cwuuuu</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E3%80%8C%E6%9D%B1%E5%A5%A7%E6%AD%A3%E5%90%8D%E3%80%8D%E8%A8%B1%E7%B6%AD%E6%99%BA%EF%BC%9A%E5%A6%82%E6%9E%9C%E5%8F%B0%E7%81%A3%E4%BA%BA%E6%B2%92%E6%9B%BF%E8%87%AA%E5%B7%B1">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Acwuuuu">搜尋看板內 cwuuuu 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467870.A.148.html">[問卦] 遲到早退什麼時候成為合理了？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">WireShark</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%81%B2%E5%88%B0%E6%97%A9%E9%80%80%E4%BB%80%E9%BA%BC%E6%99%82%E5%80%99%E6%88%90%E7%82%BA%E5%90%88%E7%90%86%E4%BA%86%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AWireShark">搜尋看板內 WireShark 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467896.A.0BC.html">[問卦] 藍綠名嘴持續激化對立，只怕會有人死亡</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">appledavid</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%97%8D%E7%B6%A0%E5%90%8D%E5%98%B4%E6%8C%81%E7%BA%8C%E6%BF%80%E5%8C%96%E5%B0%8D%E7%AB%8B%EF%BC%8C%E5%8F%AA%E6%80%95%E6%9C%83%E6%9C%89%E4%BA%BA%E6%AD%BB%E4%BA%A1">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aappledavid">搜尋看板內 appledavid 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467903.A.2C4.html">[問卦] 有沒有菜市場小瓶牛奶的八卦</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">YU0487</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%89%E6%B2%92%E6%9C%89%E8%8F%9C%E5%B8%82%E5%A0%B4%E5%B0%8F%E7%93%B6%E7%89%9B%E5%A5%B6%E7%9A%84%E5%85%AB%E5%8D%A6">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AYU0487">搜尋看板內 YU0487 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535467906.A.E70.html">[新聞] 不滿徐定禎與劉政鴻「結盟」 時代力量怒</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">cheerbu</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E4%B8%8D%E6%BB%BF%E5%BE%90%E5%AE%9A%E7%A6%8E%E8%88%87%E5%8A%89%E6%94%BF%E9%B4%BB%E3%80%8C%E7%B5%90%E7%9B%9F%E3%80%8D&#43;%E6%99%82%E4%BB%A3%E5%8A%9B%E9%87%8F%E6%80%92">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Acheerbu">搜尋看板內 cheerbu 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535468011.A.A7F.html">[問卦] 認真問 飲茶哪裡不好?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">qmqmqm</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%AA%8D%E7%9C%9F%E5%95%8F&#43;%E9%A3%B2%E8%8C%B6%E5%93%AA%E8%A3%A1%E4%B8%8D%E5%A5%BD%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aqmqmqm">搜尋看板內 qmqmqm 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/28</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1510415718.A.D77.html">[公告] 八卦板板規(2017.11.11)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Kay731</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282017.11.11%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKay731">搜尋看板內 Kay731 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">99</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1533045631.A.0B6.html">[公告] 八月份置底閒聊文</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E6%9C%88%E4%BB%BD%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E6%96%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/31</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535205047.A.283.html">[協尋] 8/24清晨岡山嘉新東路行車記錄器</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">breadbear</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;8%2F24%E6%B8%85%E6%99%A8%E5%B2%A1%E5%B1%B1%E5%98%89%E6%96%B0%E6%9D%B1%E8%B7%AF%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Abreadbear">搜尋看板內 breadbear 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/25</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535383050.A.110.html">[協尋] 8/27 AM8:00 新莊IKEA附近行車記錄器 </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jackaliao</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;8%2F27&#43;AM8%3A00&#43;%E6%96%B0%E8%8E%8AIKEA%E9%99%84%E8%BF%91%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajackaliao">搜尋看板內 jackaliao 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/27</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535036442.A.88F.html">[協尋] 8/16行車記錄器-汐止新台五路交流道</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">mike16817</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;8%2F16%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8-%E6%B1%90%E6%AD%A2%E6%96%B0%E5%8F%B0%E4%BA%94%E8%B7%AF%E4%BA%A4%E6%B5%81%E9%81%93">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Amike16817">搜尋看板內 mike16817 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %%
from requests_html import HTML

def parse_article_entries(doc):
    html = HTML(html=doc)
    post_entries = html.find('div.r-ent')
    return post_entries

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
resp = fetch(url)  # step-1
post_entries = parse_article_entries(resp.text)  # step-2

print(post_entries)  # result of setp-2
# Out:
# [<Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>]

# %%
def parse_article_meta(entry):
    '''
    每筆資料都存在 dict() 類型中：key-value paird data
    '''
    try:
        return {
            'title': entry.find('div.title', first=True).text,
            'push': entry.find('div.nrec', first=True).text,
            'date': entry.find('div.date', first=True).text,
            'author': entry.find('div.author', first=True).text,
            'link': entry.find('div.title > a', first=True).attrs['href'],
        }
    except:
        pass
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
resp = fetch(url)  # step-1
post_entries = parse_article_entries(resp.text)  # step-2

for entry in post_entries:
    meta_article = parse_article_meta(entry)
    print(meta_article)  # result of setp-3

    # pretty_print(meta['push'], meta['title'], meta['date'], meta['author'])  # for below results
# Out:
# {'title': '[問卦] 最近感冒都是咳嗽和拉肚子嗎?', 'push': '', 'date': '8/28', 'author': 'DragonQuest', 'link': '/bbs/Gossiping/M.1535467730.A.C2B.html'}
# {'title': 'Re: [新聞]川普宣布 美國與墨西哥就新貿易協定達協議', 'push': '', 'date': '8/28', 'author': 'hugh509', 'link': '/bbs/Gossiping/M.1535467770.A.507.html'}
# {'title': '[新聞] 【真愛動畫】差35歲姊弟戀\u3000開心籌備盛大', 'push': '6', 'date': '8/28', 'author': 'ymuit', 'link': '/bbs/Gossiping/M.1535467774.A.CC7.html'}
# {'title': 'Re: [問卦] 學弟最近失戀 該怎麼安慰他 :)', 'push': '', 'date': '8/28', 'author': 'cosmite', 'link': '/bbs/Gossiping/M.1535467817.A.962.html'}
# {'title': '[問卦] 吳奕凡一直說自己來自中國是??', 'push': '1', 'date': '8/28', 'author': 'gk524', 'link': '/bbs/Gossiping/M.1535467820.A.A2C.html'}
# {'title': '[新聞] 日本川崎原女大生騎電動自行車邊玩手機撞死人被判刑', 'push': '3', 'date': '8/28', 'author': 'chart', 'link': '/bbs/Gossiping/M.1535467821.A.A03.html'}
# {'title': '[問卦] 有個女的要我跟他一起找金毛鈴', 'push': '', 'date': '8/28', 'author': 'Changyaya', 'link': '/bbs/Gossiping/M.1535467830.A.48B.html'}
# {'title': '[問卦] 真的有鄉民遇到"送肉粽"跟著的嗎?', 'push': '3', 'date': '8/28', 'author': 'PasManquer', 'link': '/bbs/Gossiping/M.1535467849.A.54F.html'}
# {'title': '[問卦] 有人會用鯉魚嘴尻槍嗎？', 'push': '', 'date': '8/28', 'author': 'thegreatlcx', 'link': '/bbs/Gossiping/M.1535467864.A.995.html'}
# {'title': '[新聞] 「東奧正名」許維智：如果台灣人沒替自己', 'push': '', 'date': '8/28', 'author': 'cwuuuu', 'link': '/bbs/Gossiping/M.1535467865.A.5A5.html'}
# {'title': '[問卦] 遲到早退什麼時候成為合理了？', 'push': '', 'date': '8/28', 'author': 'WireShark', 'link': '/bbs/Gossiping/M.1535467870.A.148.html'}
# {'title': '[問卦] 藍綠名嘴持續激化對立，只怕會有人死亡', 'push': '4', 'date': '8/28', 'author': 'appledavid', 'link': '/bbs/Gossiping/M.1535467896.A.0BC.html'}
# {'title': '[問卦] 有沒有菜市場小瓶牛奶的八卦', 'push': '7', 'date': '8/28', 'author': 'YU0487', 'link': '/bbs/Gossiping/M.1535467903.A.2C4.html'}
# {'title': '[新聞] 不滿徐定禎與劉政鴻「結盟」 時代力量怒', 'push': '', 'date': '8/28', 'author': 'cheerbu', 'link': '/bbs/Gossiping/M.1535467906.A.E70.html'}
# {'title': '[問卦] 認真問 飲茶哪裡不好?', 'push': '1', 'date': '8/28', 'author': 'qmqmqm', 'link': '/bbs/Gossiping/M.1535468011.A.A7F.html'}
# {'title': '[問卦] 酸民的定義是什麽啊', 'push': '', 'date': '8/28', 'author': 'abc5588646', 'link': '/bbs/Gossiping/M.1535468047.A.B65.html'}
# {'title': '[公告] 八卦板板規(2017.11.11)', 'push': '1', 'date': '11/11', 'author': 'Kay731', 'link': '/bbs/Gossiping/M.1510415718.A.D77.html'}
# {'title': '[公告] 八月份置底閒聊文', 'push': '99', 'date': '7/31', 'author': 'RandyMarsh', 'link': '/bbs/Gossiping/M.1533045631.A.0B6.html'}
# {'title': '[協尋] 8/24清晨岡山嘉新東路行車記錄器', 'push': '6', 'date': '8/25', 'author': 'breadbear', 'link': '/bbs/Gossiping/M.1535205047.A.283.html'}
# {'title': '[協尋] 8/27 AM8:00 新莊IKEA附近行車記錄器', 'push': '13', 'date': '8/27', 'author': 'jackaliao', 'link': '/bbs/Gossiping/M.1535383050.A.110.html'}
# {'title': '[協尋] 8/16行車記錄器-汐止新台五路交流道', 'push': '5', 'date': '8/23', 'author': 'mike16817', 'link': '/bbs/Gossiping/M.1535036442.A.88F.html'}

# %%
widths = [
        (126,    1), (159,    0), (687,     1), (710,   0), (711,   1),
        (727,    0), (733,    1), (879,     0), (1154,  1), (1161,  0),
        (4347,   1), (4447,   2), (7467,    1), (7521,  0), (8369,  1),
        (8426,   0), (9000,   1), (9002,    2), (11021, 1), (12350, 2),
        (12351,  1), (12438,  2), (12442,   0), (19893, 2), (19967, 1),
        (55203,  2), (63743,  1), (64106,   2), (65039, 1), (65059, 0),
        (65131,  2), (65279,  1), (65376,   2), (65500, 1), (65510, 2),
        (120831, 1), (262141, 2), (1114109, 1),
]


def calc_len(string):
    def chr_width(o):
        global widths
        if o == 0xe or o == 0xf:
            return 0
        for num, wid in widths:
            if o <= num:
                return wid
        return 1
    return sum(chr_width(ord(c)) for c in string)


def pretty_print(push, title, date, author):
    pattern = '%3s\t%s%s%s\t%s'
    padding = ' ' * (50 - calc_len(title))
    print(pattern % (push, title, padding, date, author))

# %%
def parse_article_meta(entry):
    '''
    每筆資料都存在 dict() 類型中：key-value paird data
    '''
    return {
        'title': entry.find('div.title', first=True).text,
        'push': entry.find('div.nrec', first=True).text,
        'date': entry.find('div.date', first=True).text,
        'author': entry.find('div.author', first=True).text,
        'link': entry.find('div.title > a', first=True).attrs['href'],
    }

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
resp = fetch(url)  # step-1
post_entries = parse_article_entries(resp.text)  # step-2

for entry in post_entries:
    meta = parse_article_meta(entry)
    pretty_print(meta['push'], meta['title'], meta['date'], meta['author'])  

    # pretty_print(meta['push'], meta['title'], meta['date'], meta['author'])  # for below results
# Out:
#    	[問卦] 最近感冒都是咳嗽和拉肚子嗎?                8/28	DragonQuest
#    	Re: [新聞]川普宣布 美國與墨西哥就新貿易協定達協議 8/28	hugh509
#   6	[新聞] 【真愛動畫】差35歲姊弟戀　開心籌備盛大     8/28	ymuit
#    	Re: [問卦] 學弟最近失戀 該怎麼安慰他 :)           8/28	cosmite
#   1	[問卦] 吳奕凡一直說自己來自中國是??               8/28	gk524
#   3	[新聞] 日本川崎原女大生騎電動自行車邊玩手機撞死人被判刑8/28	chart
#    	[問卦] 有個女的要我跟他一起找金毛鈴               8/28	Changyaya
#   3	[問卦] 真的有鄉民遇到"送肉粽"跟著的嗎?            8/28	PasManquer
#    	[問卦] 有人會用鯉魚嘴尻槍嗎？                     8/28	thegreatlcx
#    	[新聞] 「東奧正名」許維智：如果台灣人沒替自己     8/28	cwuuuu
#    	[問卦] 遲到早退什麼時候成為合理了？               8/28	WireShark
#   4	[問卦] 藍綠名嘴持續激化對立，只怕會有人死亡       8/28	appledavid
#   7	[問卦] 有沒有菜市場小瓶牛奶的八卦                 8/28	YU0487
#    	[新聞] 不滿徐定禎與劉政鴻「結盟」 時代力量怒      8/28	cheerbu
#   1	[問卦] 認真問 飲茶哪裡不好?                       8/28	qmqmqm
#    	[問卦] 酸民的定義是什麽啊                         8/28	abc5588646
#   1	[公告] 八卦板板規(2017.11.11)                     11/11	Kay731
#  99	[公告] 八月份置底閒聊文                           7/31	RandyMarsh
#   6	[協尋] 8/24清晨岡山嘉新東路行車記錄器             8/25	breadbear
#  13	[協尋] 8/27 AM8:00 新莊IKEA附近行車記錄器         8/27	jackaliao
#   5	[協尋] 8/16行車記錄器-汐止新台五路交流道          8/23	mike16817

# %% [markdown]
# ### 考慮到被刪除文章

# %%
def parse_article_meta(ent):
    ''' Step-3 (revised): parse the metadata in article entry '''
    # 基本要素都還在
    meta = {
        'title': ent.find('div.title', first=True).text,
        'push': ent.find('div.nrec', first=True).text,
        'date': ent.find('div.date', first=True).text,
    }

    try:
        # 正常狀況取得資料
        meta['author'] = ent.find('div.author', first=True).text
        meta['link'] = ent.find('div.title > a', first=True).attrs['href']
    except AttributeError:
        # 但碰上文章被刪除時，就沒有辦法像原本的方法取得 作者 跟 連結
        if '(本文已被刪除)' in meta['title']:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', meta['title'])
            if match_author:
                meta['author'] = match_author.group(1)
        elif re.search('已被\w*刪除', meta['title']):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', meta['title'])
            if match_author:
                meta['author'] = match_author.group(1)
    return meta

    # 最終仍回傳統一的 dict() 形式 paired data
    return meta

# %%
import re
import urllib.parse
## from utils import pretty_print

def get_metadata_from(url):

    def parse_next_link(doc):
        domain = 'https://www.ptt.cc/' 
        html = HTML(html=doc)
        controls = html.find('.action-bar a.btn.wide')
        link = controls[1].attrs.get('href')
        return urllib.parse.urljoin(domain, link)

    resp = fetch(url)
    post_entries = parse_article_entries(resp.text)
    next_link = parse_next_link(resp.text)

    metadata = [parse_article_meta(entry) for entry in post_entries]
    return metadata, next_link

def get_paged_meta(url, num_pages):
    collected_meta = []
    domain = 'https://www.ptt.cc/'
    
    for _ in range(num_pages):
        posts, link = get_metadata_from(url)
        collected_meta += posts

        url = urllib.parse.urljoin(domain, link)

    return collected_meta

start_url = 'https://www.ptt.cc/bbs/movie/index.html'
metadata = get_paged_meta(start_url, num_pages=10)
for meta in metadata:
    pretty_print(meta['push'], meta['title'], meta['date'], meta['author'])
# Out:
# https://www.ptt.cc/bbs/movie/index7063.html
# https://www.ptt.cc/bbs/movie/index7062.html
# https://www.ptt.cc/bbs/movie/index7061.html
# https://www.ptt.cc/bbs/movie/index7060.html
# https://www.ptt.cc/bbs/movie/index7059.html
# https://www.ptt.cc/bbs/movie/index7058.html
# https://www.ptt.cc/bbs/movie/index7057.html
# https://www.ptt.cc/bbs/movie/index7056.html
# https://www.ptt.cc/bbs/movie/index7055.html
# https://www.ptt.cc/bbs/movie/index7054.html
#   1	[問片] 恐怖片                                     8/28	service1623
#   1	[情報] 平井堅,長澤雅美,山田孝之宣傳《50次初吻     8/28	KenHiraiTW
#   5	[情報] 【光點獨家】法國希區考克 - 克魯佐經典影展  8/28	qpr322
#    	[贈票]《笑畫人生》特映會 電影票十組               8/28	rosebyrne
#    	[版規] 電影版版規 201808                          8/28	VOT1077
#   8	[公告] 電影版板規修訂說明                         8/28	VOT1077
#    	[新任板主] movie 板 VOT1077                       8/28	nosweating
#   4	[贈票] 《粽邪》今晚高雄特映會                     8/28	IUismylove
#  41	Re: [新聞] 皮爾斯支持湯姆哈迪成為下一任007        8/28	chirex
#   8	Re: [請益] 瘋狂麥斯到底值不值的看?                8/28	gn02118620
#   3	[新聞]「古裝版屍速」入侵朝廷　玄彬以一擋百        8/28	moneybuy
#   7	[情報] 瑞典奧斯卡外語片代表：《邊境奇譚》         8/28	qpr322
#    	[新任板主] movie 板 VOT1077                       8/28	nosweating
#   2	[新聞] 《侏羅紀世界》最初劇本大改！ 「女主角      8/28	hahaha0204
#   5	[新聞] 窪塚洋介反悔想出席 亞太影展說NO也不考      8/28	hahaha0204
#   5	[新聞] 迪士尼串流影音服務 2019 秋季上線，首曝     8/28	hahaha0204
#  21	[問片] 一部有機器手掌的片                         8/28	rfvujm
#  17	[討論] 影評Jeff Sneider爆料多部電影試映口碑       8/28	hahaha0204
#   1	[好雷] 殺戮元年-觀後感                            8/28	forevertruth
#  10	[請益] 哭聲裡的問題                               8/28	wahahaha
#   1	[好雷] 老娘也要當間諜 The Spy Who Dumped Me       8/28	mysmalllamb
#    	[版規] 電影版版規 201808                          8/28	VOT1077
#  17	[公告] 電影版板規修訂說明                         8/28	VOT1077
#   3	[請益] 我只是個計程車司機                         8/28	wahahaha
#   4	[情報] 羅莎蒙派克、傑米道南主演新片《A Private War》首支預告公8/28	qpr322
#   2	Re: [討論] 想看台灣拍什麼恐怖片題材               8/28	march0331
#   6	[討論] 春光之境：戲內補充資料                     8/28	kyouya
#  13	[新聞] 《瘋狂亞洲富豪》撈23億 蟬聯北美票房冠      8/28	pipiboygay
#   3	[新聞] 格雷總裁交手小惡魔　《與赫夫晚餐》預告     8/28	pipiboygay
#    	[新聞] 「粽邪」票房賣破600萬 戲院發生靈異事       8/28	lpbrother
#   8	[討論] 亞歷鮑德溫加入《小丑》卡司                 8/28	alljerry04
#   8	[好雷] 與神同行-有些地方讓人不耐                  8/28	whj0530
#   2	[問片] 一部召喚陰界鬼差實現願望的片               8/28	Godspeech
#   7	[請益] 湯瑪士小火車：環遊世界大冒險好看嗎?        8/28	baga0302
#  12	[情報] 2018 韓國釜日電影獎 入圍名單               8/28	qpr322
#   8	[問片] 多重人格 視覺系 畫面美的電影               8/28	kevin81128
#   6	[好雷] 《愛的過去進行式》Netflix清新YA佳作        8/28	wanderlust
#   9	[好雷] 《史達林死了沒？》-暴政的荒謬與愚蠢        8/28	leila
#  11	[新聞] 張國榮經典重現 華語影壇最夢幻合作          8/28	reggiewang
#  43	[軟雷] 黑豹再看第二次真的覺得有夠廢+一個問題      8/28	kerkers
#  16	[片單] 主角使壞的電影                             8/28	a1l12
#  41	[新聞] 克雷格版龐德恐被賜死 導演袂爽走人          8/28	whj0530
#  29	[負雷] 瞞天過海：八面玲瓏                         8/28	plutox
#   2	[問片] 想找一部時間非線性的一部電影               8/28	hihibaby999
#   2	[問片] 一部大概是有關外星人的片子                 8/28	std92050
#  45	[討論] 想看台灣拍什麼恐怖片題材                   8/28	linccccc
#    	Re: [好雷] 在南韓的朝鮮族—黃海追緝                8/28	b94703083
#   1	[情報] 《笑傲曇天》漫畫改編真人版電影8月31日      8/27	hoanbeh
#    	(本文已被刪除) [vivianwoo]                        8/27	vivianwoo
#   9	[選片] 小偷家族vs道別的早晨就用約定之花點綴       8/27	vivianwoo
#   6	[微負雷] 太公式化的粽邪                           8/27	dawnwings
#  29	[片單] 身心障礙家長扶養小孩                       8/27	gabiihair
#    	[請益] 小時候在電視上看到的歐美電影               8/27	lynn26515
#   3	[贈票] 8/28中午私刑教育2特映券一張(已送出)        8/27	justinl
#  22	[新聞]《我們的50次初吻》長澤雅美.山田孝之問候     8/27	KenHiraiTW
#   3	[好雷] 她的錯誤教育                               8/27	wl02365109
#   5	[新聞]進軍好萊塢的日本女星忽那汐里穿女僕裝 和     8/27	ATCTaiwan
#    	[垃圾雷]玩命關頭8                                 8/27	Lindominate
#  X1	[討論] 金剛狼3羅根，是不是過譽了啊？(雷)          8/27	x111222333
#  16	[請益] 瘋狂亞洲富豪最後                           8/28	dounozebra
#   2	[問片] 一部約八年前偷窺主視角是女性的國片         8/28	abbba
#   9	[恐怖雷] 宿怨                                     8/28	ILoveSoyMilk
#   2	[普雷] 摩天大樓 吐槽滿點的片                      8/28	kelosh22
#  17	[討論]與神同行2 解怨脈的髮型                      8/28	x526542012
#  15	[片單] 跟搶房子有關電影                           8/28	yagamil18
#   4	Re: [情報] 天際浩劫2，最新預告片                  8/28	NormalX
#   1	[新聞] 郭富城《無雙》燒腦 揪發哥噴鈔票            8/28	pipiboygay
#  11	[片單] 翻拍"非賣座電影"的(商業)電影               8/27	filmystery
#   9	Re: [討論] 國片是發生什麼事了                     8/27	Magic0312
#   6	[好雷] 大師兄，甄子丹再創武打新格局               8/27	RX0UNICORN
#   4	Re: [討論] 國片是發生什麼事了                     8/27	hcbr
#  57	[片單] 玩弄觀眾的片                               8/27	JQK2
#    	Re: [問片] 很久以前的殺手片                       8/27	dorajialin
#  21	[新聞] 《德州電鋸殺人狂》故事持續拓展！傳奇影     8/27	hahaha0204
#  52	[新聞] 大眾電影獎？《黑豹》的目標是奧斯卡最佳     8/27	hahaha0204
#  17	[問片] 國片有哪些是在國內票房不好對岸卻大賣       8/27	purue
#   3	[好雷] 闇黑之心 — 一個好的開始                    8/27	walterDing
#   2	[問片] 關於單親媽媽與一對兒女的電影               8/27	MLAJF
#    	[問片] 外遇爸爸與學校老師以及一艘帆船的電影       8/27	MLAJF
#  78	[新聞] 皮爾斯支持湯姆哈迪成為下一任007            8/27	hahaha0204
#  22	[好雷] 從金牌特務2看續集電影                      8/27	Magic0312
#  43	Re: [請益] 大佛普拉斯結局到底？                   8/27	RainCoffee
#   9	[ 好雷] 烈火焚身Incedies(2010加拿大電影)          8/27	zzauber
#  11	[討論雷] 瘋狂亞洲富豪 比較電影&小說差異           8/27	eric30215
#   1	[新聞] 甄子丹化身最強教師 「大師兄」勇奪新片      8/27	alba51724
#  62	[新聞] 《櫻桃小丸子》作者53歲乳癌逝世　「過了     8/27	pipiboygay
#   2	[普雷]差了那麼一點-大佛普拉斯                     8/27	DearR
#   4	[問片] 一部1998年以前感人國片                     8/27	suweiQQ
#   3	Re: [請益] [雷]瘋狂亞洲富豪女主與媽媽談判         8/27	kuang224
#   3	[問片] 很久以前的殺手片                           8/27	YuanYuan
#    	[情報]2018 MOD微電影暨金片子創作大賽 徵件倒數     8/27	Beynerson
#    	(本文已被刪除) [yes987520]                        8/27	yes987520
#   1	[普雷] 與神同行2                                  8/27	COCOCCC
#   9	[新聞] 回眸大師：米洛斯福曼　七經典致敬　台灣史上最完整的大師8/27	qpr322
#    	[好雷]《全面霾伏》人類其實渺小到愚蠢              8/27	grafishbanet
#  29	Re: [討論] 為什麼大陸的古裝連續劇很強,電影就...?  8/27	tiara
#    	[好雷] 我願意：陸鳥與汪洋的自我成長故事           8/27	Curqder
#  22	[新聞] 「五個姐姐」確定延檔 電影公司曝原因        8/27	kellyMa
#  75	[討論] 代表作的角色感太強,導致其他作品不習慣      8/27	SEASALT
#  20	[問片] 一個關於老婆其實是來殺你的未來片           8/27	lababear
#   1	[好雷] 摩根先生的第二春 Mr.Morgan's Last Love     8/27	mysmalllamb
#   3	Re: [吵架雷] 瞞天過海8面玲瓏                      8/27	moonwind1130
#    	[新聞] 米洛斯福曼高雄電影節 回顧專題              8/27	kffkfa
#   1	Re: [討論] 為什麼大陸的古裝連續劇很強,電影就...?  8/27	visa9527
#   3	Re: [極好雷] 每天回家老婆都在裝死                 8/27	asami
#   2	Re: [吵架雷] 瞞天過海8面玲瓏                      8/27	creepygirl
#  17	[討論] 很多人覺得范保德拍的很假掰？               8/27	waynesosad
#    	(本文已被刪除) [innocent8675]                     8/26	innocent8675
#  39	[討論] 港片 人肉叉燒包                            8/26	shipping5566
#   9	Re: [新聞] 伊森霍克直言《金鋼狼 3：羅根》過譽　超 8/26	neo5277
#   1	[好無雷] 全面霾伏，面對災難的浪漫情懷             8/27	ChiaraQ1212
#   3	[好雷] 幸福路上 || 家的名字                       8/27	linda831108
#   1	[偏好雷] 拳力逃脫--緊湊的動作 未完的劇情          8/27	Rosor
#  11	[問片] 複製人但不是絕地再生（有雷）               8/27	mavis02
#  11	[請益] 香草天空                                   8/27	sunshinesam
#   2	Re: [討論] 蛇眼算很炫技的片嗎                     8/27	Abre
#   3	[問片] 人在夜晚中化為光芒的一部電影               8/27	mars111111
#   6	[討論] 恐怖片的劇情是不是能達到加分               8/27	vy8824
#   2	[請益] 闇黑之心誰正誰邪？（雷）                   8/27	birdman06
#  12	[新聞] 《空中急診英雄》打敗柯南　日本狂賣19.6     8/27	pipiboygay
#   1	[ 好雷] 繆屍 有雷                                 8/27	june0804
#    	[新聞] AKB48前成員永尾瑪利亞助陣《不能犯》演      8/27	ATCTaiwan
#   爆	Fw: [新聞] 鞏俐《唐伯虎》演得很尷尬 星爺曝秋香第  8/27	popoliii
#    	Re: [新聞] 伊森霍克直言《金鋼狼 3：羅根》過譽　超 8/27	strike519
#   7	[好無雷] 《瘋狂亞洲富豪》敍事流暢輕鬆喜劇         8/27	goodat
#  24	[新聞] 「超殺女」談性別治療爭議　新電影嚇跑       8/27	pipiboygay
#   1	[請益] 每天回家老婆都在裝死之劇中出現書名         8/27	clovererina
#  77	[新聞] 破億《花甲》落選金馬初選 黃子佼抱屈「      8/26	hahaha0204
#  49	[新聞] 伊森霍克直言《金鋼狼 3：羅根》過譽　超     8/26	hahaha0204
#   5	(本文已被刪除) [esor]                             8/26	esor
#  29	Re: [討論] 為什麼大陸的古裝連續劇很強,電影就...?  8/26	HyperPoro
#    	(本文已被刪除) [thatsgreat]                       8/26	thatsgreat
#   1	[問片] 問一部警匪片                               8/26	bbbyes123
#  34	[討論] 鐘點戰會出續集或是前傳嗎                   8/26	PJEZ
#  10	[心得] 《大師兄》Big Brother                      8/26	tuhsiaofu
#    	(本文已被刪除) [gaminnnene]                       8/26	gaminnnene
#   4	[問片] 香港恐怖系列片                             8/26	CTjoey
#   3	[問片] 國片 在計程車上面對話                      8/26	wise2525
#   5	Re: [新聞] 伊森霍克直言《金鋼狼 3：羅根》過譽　超 8/26	hayuyang
#  41	Re: [討論] 傑森史塔森...                          8/26	ckny
#   2	Re: [討論] 為什麼大陸的古裝連續劇很強,電影就...?  8/26	zeumax
#    	[好雷]《大師兄》Welcome to my class!              8/26	benbenson12
#   5	[好雷] 討論度不多，卻很好看的 <闇黑之心>          8/26	wxvwxv
#  12	[負無雷]大師兄                                    8/26	mike0285
#  17	[普好雷] 宮崎駿的第一部電影 魯邦三世              8/26	Tosca
#   7	[問片] 距今大約10年以上的外星片                   8/26	x25628014
#   5	Re: [討論] 角頭2 還是不懂為什麼阿標(黃騰浩)       8/26	wegary
#   2	[好雷] 人類升級                                   8/26	gaiaesque
#   1	[問片] 找一部失語的溫馨動畫                       8/26	ffreakk
#  44	[討論] 傑森史塔森...                              8/26	thatsgreat
#  29	[新聞] 每年普渡就想起！班導禁看魔法阿嬤「她忍     8/26	hoanbeh
#   1	[討論] 蛇眼算很炫技的片嗎                         8/26	tools
#    	[新聞] 柯比摘奧動畫片「親愛的籃球」 前進台中動畫影展8/26	orz44444
#   6	Re: [討論] 國片是發生什麼事了                     8/26	ez910115
#   2	Re: [吵架雷] 瞞天過海8面玲瓏                      8/26	damnright
#   1	[片單] 兒女向父母提起當初父母對他們的約定         8/26	Gary9163
#   2	[負雷] 粽邪。完美的恐怖片架構史料片               8/26	chucklu
#    	(本文已被刪除) [yyhong68]                         8/26	yyhong68
#    	(本文已被刪除) [TONY7]                            8/26	TONY7
#   6	[普雷] 還可以看的《粽邪》                         8/26	w854105
#   1	Re: [討論] 殺戮元年                               8/26	hoifly
#    	Re: [討論] 國片是發生什麼事了                     8/26	a874622
#  30	[討論] 為什麼大陸的古裝連續劇很強,電影就...?      8/26	mark999jrpan
#   4	[影評] 聞天祥評 / 她的錯誤教育                    8/26	MyAll
#  19	[請益] 為何電影結局大多是公理正義獲得伸張?        8/26	pipiboygay
#  12	[問片] 氣壓瓶殺人                                 8/26	yu76
#   4	[問片] 一群人在山上遇到被綁架的小女孩             8/26	s511320
#   8	Re: [討論] 國片是發生什麼事了                     8/26	dlevel
#   6	Re: [討論] 國片是發生什麼事了                     8/26	lpbrother
#   1	[普雷] 分不清是恐怖還是喜劇的粽邪                 8/26	GreenSheep
#   7	[問片] 在玻璃帷幕大樓上面爬                       8/26	Rosor
#   5	[問片] 女孩陪爸爸去探望智障的舅舅                 8/26	tieamonk
#    	[ 雷] 「每天回家老婆都在裝死」                    8/26	aaa955051
#  26	[選片] 與神2 殺戮元年 亞洲富豪                    8/26	uglytrue
#   4	[大負雷] 全面突襲2 又假又爛                       8/26	overlay
#  22	[問片] 水上浮油 會吃人                            8/26	coda17
#  58	[討論] 槍支使用完的處理                           8/26	awesome123
#   8	[新聞] 全亞裔《喜福會》有望拍續集或劇集           8/26	qpr322
#  12	[超好雷] 春光之境：並不是英國斷背山               8/26	kyouya
#   2	[好雷] 《我願意》哪怕只剩回憶                     8/26	bestbamboo
#    	[討論] "我願意"原型人物的真實命運還真慘(微雷)     8/26	pipiboygay
#  14	Re: [討論] 國片是發生什麼事了                     8/26	z800218
#    	(本文已被刪除) [grafishbanet]                     8/26	grafishbanet
#  14	[轉錄] 有沒有黑金這部電影的八卦                   8/26	Reewalker
#   1	[普雷]《殺戮元年》不關心政治，等著被笨蛋統治      8/26	grafishbanet
#   9	[負雷]噤界小心得                                  8/26	devil0915
#  11	[好無雷] 文戲武戲都精采的大師兄                   8/26	generalfungi

# %%
import time
from multiprocessing import Pool

domain = 'https://www.ptt.cc/'

def get_posts(metadata):
    # 將所有文章連結收集並串接成完整 URL
    post_links = [
        urllib.parse.urljoin(domain, meta['link'])
        for meta in metadata if 'link' in meta
    ]

    with Pool(processes=3) as pool:
        contents = pool.map(fetch, post_links)
        return contents

if __name__ == '__main__':
    pages = 5

    start = time.time()

    metadata = get_paged_meta(start_url, num_pages=pages)
    resps = get_posts(metadata)

    print('花費: %f 秒' % (time.time() - start))

    print('共%d項結果：' % len(resps))
    for post, resps in zip(metadata, resps):
        print('{0} {1: <15} {2}, 網頁內容共 {3} 字'.format(
            post['date'], post['author'], post['title'], len(resps.text)))
# Out:
# https://www.ptt.cc/bbs/movie/index7063.html
# https://www.ptt.cc/bbs/movie/index7062.html
# https://www.ptt.cc/bbs/movie/index7061.html
# https://www.ptt.cc/bbs/movie/index7060.html
# https://www.ptt.cc/bbs/movie/index7059.html
# 花費: 99.935249 秒
# 共86項結果：
# 8/28 service1623     [問片] 恐怖片, 網頁內容共 5337 字
# 8/28 KenHiraiTW      [情報] 平井堅,長澤雅美,山田孝之宣傳《50次初吻, 網頁內容共 7835 字
# 8/28 qpr322          [情報] 【光點獨家】法國希區考克 - 克魯佐經典影展, 網頁內容共 6586 字
# 8/28 rosebyrne       [贈票]《笑畫人生》特映會 電影票十組, 網頁內容共 6149 字
# 8/28 VOT1077         [版規] 電影版版規 201808, 網頁內容共 11441 字
# 8/28 VOT1077         [公告] 電影版板規修訂說明, 網頁內容共 46850 字
# 8/28 nosweating      [新任板主] movie 板 VOT1077, 網頁內容共 5170 字
# 8/28 IUismylove      [贈票] 《粽邪》今晚高雄特映會, 網頁內容共 5577 字
# 8/28 chirex          Re: [新聞] 皮爾斯支持湯姆哈迪成為下一任007, 網頁內容共 25429 字
# 8/28 gn02118620      Re: [請益] 瘋狂麥斯到底值不值的看?, 網頁內容共 15250 字
# 8/28 moneybuy        [新聞]「古裝版屍速」入侵朝廷　玄彬以一擋百, 網頁內容共 6741 字
# 8/28 qpr322          [情報] 瑞典奧斯卡外語片代表：《邊境奇譚》, 網頁內容共 12366 字
# 8/28 nosweating      [新任板主] movie 板 VOT1077, 網頁內容共 5170 字
# 8/28 hahaha0204      [新聞] 《侏羅紀世界》最初劇本大改！ 「女主角, 網頁內容共 6839 字
# 8/28 hahaha0204      [新聞] 窪塚洋介反悔想出席 亞太影展說NO也不考, 網頁內容共 7997 字
# 8/28 hahaha0204      [新聞] 迪士尼串流影音服務 2019 秋季上線，首曝, 網頁內容共 8045 字
# 8/28 rfvujm          [問片] 一部有機器手掌的片, 網頁內容共 9821 字
# 8/28 hahaha0204      [討論] 影評Jeff Sneider爆料多部電影試映口碑, 網頁內容共 13599 字
# 8/28 forevertruth    [好雷] 殺戮元年-觀後感, 網頁內容共 5046 字
# 8/28 wahahaha        [請益] 哭聲裡的問題, 網頁內容共 8104 字
# 8/28 mysmalllamb     [好雷] 老娘也要當間諜 The Spy Who Dumped Me, 網頁內容共 7478 字
# 8/28 VOT1077         [版規] 電影版版規 201808, 網頁內容共 11441 字
# 8/28 VOT1077         [公告] 電影版板規修訂說明, 網頁內容共 46850 字
# 8/28 wahahaha        [請益] 我只是個計程車司機, 網頁內容共 5363 字
# 8/28 qpr322          [情報] 羅莎蒙派克、傑米道南主演新片《A Private War》首支預告公, 網頁內容共 9670 字
# 8/28 march0331       Re: [討論] 想看台灣拍什麼恐怖片題材, 網頁內容共 5399 字
# 8/28 kyouya          [討論] 春光之境：戲內補充資料, 網頁內容共 8376 字
# 8/28 pipiboygay      [新聞] 《瘋狂亞洲富豪》撈23億 蟬聯北美票房冠, 網頁內容共 11055 字
# 8/28 pipiboygay      [新聞] 格雷總裁交手小惡魔　《與赫夫晚餐》預告, 網頁內容共 6295 字
# 8/28 lpbrother       [新聞] 「粽邪」票房賣破600萬 戲院發生靈異事, 網頁內容共 12297 字
# 8/28 alljerry04      [討論] 亞歷鮑德溫加入《小丑》卡司, 網頁內容共 8863 字
# 8/28 whj0530         [好雷] 與神同行-有些地方讓人不耐, 網頁內容共 7933 字
# 8/28 Godspeech       [問片] 一部召喚陰界鬼差實現願望的片, 網頁內容共 5747 字
# 8/28 baga0302        [請益] 湯瑪士小火車：環遊世界大冒險好看嗎?, 網頁內容共 6608 字
# 8/28 qpr322          [情報] 2018 韓國釜日電影獎 入圍名單, 網頁內容共 10867 字
# 8/28 kevin81128      [問片] 多重人格 視覺系 畫面美的電影, 網頁內容共 8364 字
# 8/28 wanderlust      [好雷] 《愛的過去進行式》Netflix清新YA佳作, 網頁內容共 11906 字
# 8/28 leila           [好雷] 《史達林死了沒？》-暴政的荒謬與愚蠢, 網頁內容共 9542 字
# 8/28 reggiewang      [新聞] 張國榮經典重現 華語影壇最夢幻合作, 網頁內容共 9404 字
# 8/28 kerkers         [軟雷] 黑豹再看第二次真的覺得有夠廢+一個問題, 網頁內容共 21254 字
# 8/28 a1l12           [片單] 主角使壞的電影, 網頁內容共 10810 字
# 8/28 whj0530         [新聞] 克雷格版龐德恐被賜死 導演袂爽走人, 網頁內容共 18993 字
# 8/28 plutox          [負雷] 瞞天過海：八面玲瓏, 網頁內容共 22385 字
# 8/28 hihibaby999     [問片] 想找一部時間非線性的一部電影, 網頁內容共 6250 字
# 8/28 std92050        [問片] 一部大概是有關外星人的片子, 網頁內容共 6530 字
# 8/28 linccccc        [討論] 想看台灣拍什麼恐怖片題材, 網頁內容共 19564 字
# 8/28 b94703083       Re: [好雷] 在南韓的朝鮮族—黃海追緝, 網頁內容共 5536 字
# 8/27 hoanbeh         [情報] 《笑傲曇天》漫畫改編真人版電影8月31日, 網頁內容共 7116 字
# 8/27 vivianwoo       (本文已被刪除) [vivianwoo], 網頁內容共 7261 字
# 8/27 vivianwoo       [選片] 小偷家族vs道別的早晨就用約定之花點綴, 網頁內容共 9142 字
# 8/27 dawnwings       [微負雷] 太公式化的粽邪, 網頁內容共 13761 字
# 8/27 gabiihair       [片單] 身心障礙家長扶養小孩, 網頁內容共 5993 字
# 8/27 lynn26515       [請益] 小時候在電視上看到的歐美電影, 網頁內容共 6094 字
# 8/27 justinl         [贈票] 8/28中午私刑教育2特映券一張(已送出), 網頁內容共 12260 字
# 8/27 KenHiraiTW      [新聞]《我們的50次初吻》長澤雅美.山田孝之問候, 網頁內容共 10869 字
# 8/27 wl02365109      [好雷] 她的錯誤教育, 網頁內容共 7580 字
# 8/27 ATCTaiwan       [新聞]進軍好萊塢的日本女星忽那汐里穿女僕裝 和, 網頁內容共 9340 字
# 8/27 Lindominate     [垃圾雷]玩命關頭8, 網頁內容共 25425 字
# 8/27 x111222333      [討論] 金剛狼3羅根，是不是過譽了啊？(雷), 網頁內容共 10791 字
# 8/28 dounozebra      [請益] 瘋狂亞洲富豪最後, 網頁內容共 5079 字
# 8/28 abbba           [問片] 一部約八年前偷窺主視角是女性的國片, 網頁內容共 8680 字
# 8/28 ILoveSoyMilk    [恐怖雷] 宿怨, 網頁內容共 7001 字
# 8/28 kelosh22        [普雷] 摩天大樓 吐槽滿點的片, 網頁內容共 11786 字
# 8/28 x526542012      [討論]與神同行2 解怨脈的髮型, 網頁內容共 8711 字
# 8/28 yagamil18       [片單] 跟搶房子有關電影, 網頁內容共 8264 字
# 8/28 NormalX         Re: [情報] 天際浩劫2，最新預告片, 網頁內容共 5484 字
# 8/28 pipiboygay      [新聞] 郭富城《無雙》燒腦 揪發哥噴鈔票, 網頁內容共 11176 字
# 8/27 filmystery      [片單] 翻拍"非賣座電影"的(商業)電影, 網頁內容共 10587 字
# 8/27 Magic0312       Re: [討論] 國片是發生什麼事了, 網頁內容共 9270 字
# 8/27 RX0UNICORN      [好雷] 大師兄，甄子丹再創武打新格局, 網頁內容共 12431 字
# 8/27 hcbr            Re: [討論] 國片是發生什麼事了, 網頁內容共 20942 字
# 8/27 JQK2            [片單] 玩弄觀眾的片, 網頁內容共 4724 字
# 8/27 dorajialin      Re: [問片] 很久以前的殺手片, 網頁內容共 11921 字
# 8/27 hahaha0204      [新聞] 《德州電鋸殺人狂》故事持續拓展！傳奇影, 網頁內容共 26603 字
# 8/27 hahaha0204      [新聞] 大眾電影獎？《黑豹》的目標是奧斯卡最佳, 網頁內容共 12304 字
# 8/27 purue           [問片] 國片有哪些是在國內票房不好對岸卻大賣, 網頁內容共 6606 字
# 8/27 walterDing      [好雷] 闇黑之心 — 一個好的開始, 網頁內容共 5531 字
# 8/27 MLAJF           [問片] 關於單親媽媽與一對兒女的電影, 網頁內容共 4833 字
# 8/27 MLAJF           [問片] 外遇爸爸與學校老師以及一艘帆船的電影, 網頁內容共 30648 字
# 8/27 hahaha0204      [新聞] 皮爾斯支持湯姆哈迪成為下一任007, 網頁內容共 19028 字
# 8/27 Magic0312       [好雷] 從金牌特務2看續集電影, 網頁內容共 16726 字
# 8/27 RainCoffee      Re: [請益] 大佛普拉斯結局到底？, 網頁內容共 8614 字
# 8/27 zzauber         [ 好雷] 烈火焚身Incedies(2010加拿大電影), 網頁內容共 13534 字
# 8/27 eric30215       [討論雷] 瘋狂亞洲富豪 比較電影&小說差異, 網頁內容共 5486 字
# 8/27 alba51724       [新聞] 甄子丹化身最強教師 「大師兄」勇奪新片, 網頁內容共 25414 字
# 8/27 pipiboygay      [新聞] 《櫻桃小丸子》作者53歲乳癌逝世　「過了, 網頁內容共 7197 字

# %%
import time
from multiprocessing import Pool

domain = 'https://www.ptt.cc/'

def get_posts(metadata):
    # 將所有文章連結收集並串接成完整 URL
    post_links = [
        urllib.parse.urljoin(domain, meta['link'])
        for meta in metadata if 'link' in meta
    ]

    with Pool(processes=6) as pool:
        contents = pool.map(fetch, post_links)
        return contents

if __name__ == '__main__':
    pages = 5

    start = time.time()

    metadata = get_paged_meta(start_url, num_pages=pages)
    resps = get_posts(metadata)

    print('花費: %f 秒' % (time.time() - start))

    print('共%d項結果：' % len(resps))
    for post, resps in zip(metadata, resps):
        print('{0} {1: <15} {2}, 網頁內容共 {3} 字'.format(
            post['date'], post['author'], post['title'], len(resps.text)))
# Out:
# https://www.ptt.cc/bbs/movie/index7063.html
# https://www.ptt.cc/bbs/movie/index7062.html
# https://www.ptt.cc/bbs/movie/index7061.html
# https://www.ptt.cc/bbs/movie/index7060.html
# https://www.ptt.cc/bbs/movie/index7059.html
# 花費: 123.451517 秒
# 共86項結果：
# 8/28 service1623     [問片] 恐怖片, 網頁內容共 5337 字
# 8/28 KenHiraiTW      [情報] 平井堅,長澤雅美,山田孝之宣傳《50次初吻, 網頁內容共 7835 字
# 8/28 qpr322          [情報] 【光點獨家】法國希區考克 - 克魯佐經典影展, 網頁內容共 6586 字
# 8/28 rosebyrne       [贈票]《笑畫人生》特映會 電影票十組, 網頁內容共 6149 字
# 8/28 VOT1077         [版規] 電影版版規 201808, 網頁內容共 11441 字
# 8/28 VOT1077         [公告] 電影版板規修訂說明, 網頁內容共 46850 字
# 8/28 nosweating      [新任板主] movie 板 VOT1077, 網頁內容共 5170 字
# 8/28 IUismylove      [贈票] 《粽邪》今晚高雄特映會, 網頁內容共 5577 字
# 8/28 chirex          Re: [新聞] 皮爾斯支持湯姆哈迪成為下一任007, 網頁內容共 25429 字
# 8/28 gn02118620      Re: [請益] 瘋狂麥斯到底值不值的看?, 網頁內容共 15250 字
# 8/28 moneybuy        [新聞]「古裝版屍速」入侵朝廷　玄彬以一擋百, 網頁內容共 6741 字
# 8/28 qpr322          [情報] 瑞典奧斯卡外語片代表：《邊境奇譚》, 網頁內容共 12366 字
# 8/28 nosweating      [新任板主] movie 板 VOT1077, 網頁內容共 5170 字
# 8/28 hahaha0204      [新聞] 《侏羅紀世界》最初劇本大改！ 「女主角, 網頁內容共 6839 字
# 8/28 hahaha0204      [新聞] 窪塚洋介反悔想出席 亞太影展說NO也不考, 網頁內容共 7997 字
# 8/28 hahaha0204      [新聞] 迪士尼串流影音服務 2019 秋季上線，首曝, 網頁內容共 8045 字
# 8/28 rfvujm          [問片] 一部有機器手掌的片, 網頁內容共 9821 字
# 8/28 hahaha0204      [討論] 影評Jeff Sneider爆料多部電影試映口碑, 網頁內容共 13599 字
# 8/28 forevertruth    [好雷] 殺戮元年-觀後感, 網頁內容共 5046 字
# 8/28 wahahaha        [請益] 哭聲裡的問題, 網頁內容共 8104 字
# 8/28 mysmalllamb     [好雷] 老娘也要當間諜 The Spy Who Dumped Me, 網頁內容共 7478 字
# 8/28 VOT1077         [版規] 電影版版規 201808, 網頁內容共 11441 字
# 8/28 VOT1077         [公告] 電影版板規修訂說明, 網頁內容共 46850 字
# 8/28 wahahaha        [請益] 我只是個計程車司機, 網頁內容共 5363 字
# 8/28 qpr322          [情報] 羅莎蒙派克、傑米道南主演新片《A Private War》首支預告公, 網頁內容共 9670 字
# 8/28 march0331       Re: [討論] 想看台灣拍什麼恐怖片題材, 網頁內容共 5399 字
# 8/28 kyouya          [討論] 春光之境：戲內補充資料, 網頁內容共 8376 字
# 8/28 pipiboygay      [新聞] 《瘋狂亞洲富豪》撈23億 蟬聯北美票房冠, 網頁內容共 11055 字
# 8/28 pipiboygay      [新聞] 格雷總裁交手小惡魔　《與赫夫晚餐》預告, 網頁內容共 6295 字
# 8/28 lpbrother       [新聞] 「粽邪」票房賣破600萬 戲院發生靈異事, 網頁內容共 12297 字
# 8/28 alljerry04      [討論] 亞歷鮑德溫加入《小丑》卡司, 網頁內容共 8863 字
# 8/28 whj0530         [好雷] 與神同行-有些地方讓人不耐, 網頁內容共 7933 字
# 8/28 Godspeech       [問片] 一部召喚陰界鬼差實現願望的片, 網頁內容共 5747 字
# 8/28 baga0302        [請益] 湯瑪士小火車：環遊世界大冒險好看嗎?, 網頁內容共 6608 字
# 8/28 qpr322          [情報] 2018 韓國釜日電影獎 入圍名單, 網頁內容共 10867 字
# 8/28 kevin81128      [問片] 多重人格 視覺系 畫面美的電影, 網頁內容共 8364 字
# 8/28 wanderlust      [好雷] 《愛的過去進行式》Netflix清新YA佳作, 網頁內容共 11906 字
# 8/28 leila           [好雷] 《史達林死了沒？》-暴政的荒謬與愚蠢, 網頁內容共 9542 字
# 8/28 reggiewang      [新聞] 張國榮經典重現 華語影壇最夢幻合作, 網頁內容共 9404 字
# 8/28 kerkers         [軟雷] 黑豹再看第二次真的覺得有夠廢+一個問題, 網頁內容共 21254 字
# 8/28 a1l12           [片單] 主角使壞的電影, 網頁內容共 10810 字
# 8/28 whj0530         [新聞] 克雷格版龐德恐被賜死 導演袂爽走人, 網頁內容共 18993 字
# 8/28 plutox          [負雷] 瞞天過海：八面玲瓏, 網頁內容共 22385 字
# 8/28 hihibaby999     [問片] 想找一部時間非線性的一部電影, 網頁內容共 6250 字
# 8/28 std92050        [問片] 一部大概是有關外星人的片子, 網頁內容共 6530 字
# 8/28 linccccc        [討論] 想看台灣拍什麼恐怖片題材, 網頁內容共 19564 字
# 8/28 b94703083       Re: [好雷] 在南韓的朝鮮族—黃海追緝, 網頁內容共 5536 字
# 8/27 hoanbeh         [情報] 《笑傲曇天》漫畫改編真人版電影8月31日, 網頁內容共 7116 字
# 8/27 vivianwoo       (本文已被刪除) [vivianwoo], 網頁內容共 7261 字
# 8/27 vivianwoo       [選片] 小偷家族vs道別的早晨就用約定之花點綴, 網頁內容共 9142 字
# 8/27 dawnwings       [微負雷] 太公式化的粽邪, 網頁內容共 13761 字
# 8/27 gabiihair       [片單] 身心障礙家長扶養小孩, 網頁內容共 5993 字
# 8/27 lynn26515       [請益] 小時候在電視上看到的歐美電影, 網頁內容共 6094 字
# 8/27 justinl         [贈票] 8/28中午私刑教育2特映券一張(已送出), 網頁內容共 12260 字
# 8/27 KenHiraiTW      [新聞]《我們的50次初吻》長澤雅美.山田孝之問候, 網頁內容共 10869 字
# 8/27 wl02365109      [好雷] 她的錯誤教育, 網頁內容共 7580 字
# 8/27 ATCTaiwan       [新聞]進軍好萊塢的日本女星忽那汐里穿女僕裝 和, 網頁內容共 9340 字
# 8/27 Lindominate     [垃圾雷]玩命關頭8, 網頁內容共 25425 字
# 8/27 x111222333      [討論] 金剛狼3羅根，是不是過譽了啊？(雷), 網頁內容共 10791 字
# 8/28 dounozebra      [請益] 瘋狂亞洲富豪最後, 網頁內容共 5079 字
# 8/28 abbba           [問片] 一部約八年前偷窺主視角是女性的國片, 網頁內容共 8680 字
# 8/28 ILoveSoyMilk    [恐怖雷] 宿怨, 網頁內容共 7001 字
# 8/28 kelosh22        [普雷] 摩天大樓 吐槽滿點的片, 網頁內容共 11786 字
# 8/28 x526542012      [討論]與神同行2 解怨脈的髮型, 網頁內容共 8711 字
# 8/28 yagamil18       [片單] 跟搶房子有關電影, 網頁內容共 8264 字
# 8/28 NormalX         Re: [情報] 天際浩劫2，最新預告片, 網頁內容共 5484 字
# 8/28 pipiboygay      [新聞] 郭富城《無雙》燒腦 揪發哥噴鈔票, 網頁內容共 11176 字
# 8/27 filmystery      [片單] 翻拍"非賣座電影"的(商業)電影, 網頁內容共 10587 字
# 8/27 Magic0312       Re: [討論] 國片是發生什麼事了, 網頁內容共 9270 字
# 8/27 RX0UNICORN      [好雷] 大師兄，甄子丹再創武打新格局, 網頁內容共 12431 字
# 8/27 hcbr            Re: [討論] 國片是發生什麼事了, 網頁內容共 20942 字
# 8/27 JQK2            [片單] 玩弄觀眾的片, 網頁內容共 4724 字
# 8/27 dorajialin      Re: [問片] 很久以前的殺手片, 網頁內容共 11921 字
# 8/27 hahaha0204      [新聞] 《德州電鋸殺人狂》故事持續拓展！傳奇影, 網頁內容共 26603 字
# 8/27 hahaha0204      [新聞] 大眾電影獎？《黑豹》的目標是奧斯卡最佳, 網頁內容共 12304 字
# 8/27 purue           [問片] 國片有哪些是在國內票房不好對岸卻大賣, 網頁內容共 6606 字
# 8/27 walterDing      [好雷] 闇黑之心 — 一個好的開始, 網頁內容共 5531 字
# 8/27 MLAJF           [問片] 關於單親媽媽與一對兒女的電影, 網頁內容共 4833 字
# 8/27 MLAJF           [問片] 外遇爸爸與學校老師以及一艘帆船的電影, 網頁內容共 30648 字
# 8/27 hahaha0204      [新聞] 皮爾斯支持湯姆哈迪成為下一任007, 網頁內容共 19028 字
# 8/27 Magic0312       [好雷] 從金牌特務2看續集電影, 網頁內容共 16726 字
# 8/27 RainCoffee      Re: [請益] 大佛普拉斯結局到底？, 網頁內容共 8614 字
# 8/27 zzauber         [ 好雷] 烈火焚身Incedies(2010加拿大電影), 網頁內容共 13534 字
# 8/27 eric30215       [討論雷] 瘋狂亞洲富豪 比較電影&小說差異, 網頁內容共 5486 字
# 8/27 alba51724       [新聞] 甄子丹化身最強教師 「大師兄」勇奪新片, 網頁內容共 25414 字
# 8/27 pipiboygay      [新聞] 《櫻桃小丸子》作者53歲乳癌逝世　「過了, 網頁內容共 7197 字
