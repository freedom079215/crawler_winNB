# %%
import requests
import os
import re
import sys
import json
import requests
import argparse
import time
import codecs
from bs4 import BeautifulSoup
from six import u

# %%
import requests

def fetch(url):
    response = requests.get(url)
    response = requests.get(url, cookies={'over18': '1'})  # 一直向 server 回答滿 18 歲了 !
    return response

url = 'https://www.ptt.cc/bbs/movie/index.html'
resp = fetch(url)  # step-1

print(resp.text) # result of setp-1
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 movie 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.26/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.26/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.26/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.26/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.26/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/movie/index.html"><span class="board-label">看板 </span>movie</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/movie/index.html">看板</a>
# 				<a class="btn" href="/man/movie/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/movie/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/movie/index8191.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/movie/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564360320.A.6A5.html">Re: [新聞] 迪士尼接手阿凡達續集3大理由恐成風險</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">btm978952</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/movie/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E8%BF%AA%E5%A3%AB%E5%B0%BC%E6%8E%A5%E6%89%8B%E9%98%BF%E5%87%A1%E9%81%94%E7%BA%8C%E9%9B%863%E5%A4%A7%E7%90%86%E7%94%B1%E6%81%90%E6%88%90%E9%A2%A8%E9%9A%AA">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/movie/search?q=author%3Abtm978952">搜尋看板內 btm978952 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">56</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564360516.A.ED2.html">[新聞] 迪士尼打破單一公司年度總票房紀錄</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ooic</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/movie/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E8%BF%AA%E5%A3%AB%E5%B0%BC%E6%89%93%E7%A0%B4%E5%96%AE%E4%B8%80%E5%85%AC%E5%8F%B8%E5%B9%B4%E5%BA%A6%E7%B8%BD%E7%A5%A8%E6%88%BF%E7%B4%80%E9%8C%84">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/movie/search?q=author%3Aooic">搜尋看板內 ooic 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564366055.A.CC3.html">[普雷] 獅子王寫實版</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">zoiagapo</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/movie/search?q=thread%3A%5B%E6%99%AE%E9%9B%B7%5D&#43;%E7%8D%85%E5%AD%90%E7%8E%8B%E5%AF%AB%E5%AF%A6%E7%89%88">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/movie/search?q=author%3Azoiagapo">搜尋看板內 zoiagapo 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">11</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564368050.A.D3B.html">[討論] 復仇者聯盟4可以得幾個奧斯卡?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">h2030625</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/movie/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D&#43;%E5%BE%A9%E4%BB%87%E8%80%85%E8%81%AF%E7%9B%9F4%E5%8F%AF%E4%BB%A5%E5%BE%97%E5%B9%BE%E5%80%8B%E5%A5%A7%E6%96%AF%E5%8D%A1%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/movie/search?q=author%3Ah2030625">搜尋看板內 h2030625 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564369347.A.643.html">Fw: [問卦] 台灣都看不到香港電影了嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">icrose</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/movie/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%8F%B0%E7%81%A3%E9%83%BD%E7%9C%8B%E4%B8%8D%E5%88%B0%E9%A6%99%E6%B8%AF%E9%9B%BB%E5%BD%B1%E4%BA%86%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/movie/search?q=author%3Aicrose">搜尋看板內 icrose 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">9</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564370106.A.84D.html">[新聞] 《獅子王》連2周登北美票房冠軍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">hvariables</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/movie/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E3%80%8A%E7%8D%85%E5%AD%90%E7%8E%8B%E3%80%8B%E9%80%A32%E5%91%A8%E7%99%BB%E5%8C%97%E7%BE%8E%E7%A5%A8%E6%88%BF%E5%86%A0%E8%BB%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/movie/search?q=author%3Ahvariables">搜尋看板內 hvariables 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564370979.A.6BC.html">Fw: [贈送] 電影 鏗鏘玫瑰 兌換券 只剩高雄場</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">s89056</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/movie/search?q=thread%3A%5B%E8%B4%88%E9%80%81%5D&#43;%E9%9B%BB%E5%BD%B1&#43;%E9%8F%97%E9%8F%98%E7%8E%AB%E7%91%B0&#43;%E5%85%8C%E6%8F%9B%E5%88%B8&#43;%E5%8F%AA%E5%89%A9%E9%AB%98%E9%9B%84%E5%A0%B4">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/movie/search?q=author%3As89056">搜尋看板內 s89056 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/29</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">8</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/movie/M.1564371403.A.D43.html">Re: [討論] 復仇者聯盟4可以得幾個奧斯卡?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">
element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>, <Element 'div' class=('r-ent',)>]

# %%
def parse_article_meta(entry):
    '''
    每筆資料都存在 dict() 類型中：key-value paird data
    '''
    return {
        'title': entry.find('div.title', first=True).text,
        'push': entry.find('div.nrec', first=True).text,
        'date': entry.find('div.date', first=True).text,
        'author': entry.find('div.author', first=True).text,
        'link': entry.find('div.title > a', first=True).attrs['href'],
    }

url = 'https://www.ptt.cc/bbs/movie/index.html'
resp = fetch(url)  # step-1
post_entries = parse_article_entries(resp.text)  # step-2

for entry in post_entries:
    meta = parse_article_meta(entry)
    print(meta)  # result of setp-3

    # pretty_print(meta['push'], meta['title'], meta['date'], meta['author'])  # for below results
# Out:
# {'title': 'Re: [新聞] 迪士尼接手阿凡達續集3大理由恐成風險', 'push': '13', 'date': '7/29', 'author': 'btm978952', 'link': '/bbs/movie/M.1564360320.A.6A5.html'}
# {'title': '[新聞] 迪士尼打破單一公司年度總票房紀錄', 'push': '56', 'date': '7/29', 'author': 'ooic', 'link': '/bbs/movie/M.1564360516.A.ED2.html'}
# {'title': '[普雷] 獅子王寫實版', 'push': '5', 'date': '7/29', 'author': 'zoiagapo', 'link': '/bbs/movie/M.1564366055.A.CC3.html'}
# {'title': '[討論] 復仇者聯盟4可以得幾個奧斯卡?', 'push': '11', 'date': '7/29', 'author': 'h2030625', 'link': '/bbs/movie/M.1564368050.A.D3B.html'}
# {'title': 'Fw: [問卦] 台灣都看不到香港電影了嗎？', 'push': '', 'date': '7/29', 'author': 'icrose', 'link': '/bbs/movie/M.1564369347.A.643.html'}
# {'title': '[新聞] 《獅子王》連2周登北美票房冠軍', 'push': '9', 'date': '7/29', 'author': 'hvariables', 'link': '/bbs/movie/M.1564370106.A.84D.html'}
# {'title': 'Fw: [贈送] 電影 鏗鏘玫瑰 兌換券 只剩高雄場', 'push': '', 'date': '7/29', 'author': 's89056', 'link': '/bbs/movie/M.1564370979.A.6BC.html'}
# {'title': 'Re: [討論] 復仇者聯盟4可以得幾個奧斯卡?', 'push': '8', 'date': '7/29', 'author': 'ericisfish', 'link': '/bbs/movie/M.1564371403.A.D43.html'}
# {'title': '[新聞]涉貧富懸殊題材 韓片《寄生上流》遭大陸撤', 'push': '2', 'date': '7/29', 'author': 'CLV518', 'link': '/bbs/movie/M.1564372415.A.362.html'}
# {'title': '[請益] 電流大戰中的問題討論 有雷', 'push': '1', 'date': '7/29', 'author': 'hiu', 'link': '/bbs/movie/M.1564372804.A.0E8.html'}
# {'title': '[新聞] 復仇者4官方NG片曝光！幕後&刪減分享', 'push': '', 'date': '7/29', 'author': 'CYKONGG', 'link': '/bbs/movie/M.1564373214.A.E2A.html'}
# {'title': '[公告] 板規 2019/07/05', 'push': '22', 'date': '6/04', 'author': 'ckshchen', 'link': '/bbs/movie/M.1559611458.A.DCA.html'}
# {'title': 'Fw: [公告] 8/3 停機公告', 'push': '', 'date': '7/13', 'author': 'hhwang', 'link': '/bbs/movie/M.1563011034.A.0FC.html'}
# {'title': 'Fw: [公告] 批踢踢流行語大賞暨風雲人物投票開始', 'push': '2', 'date': '7/21', 'author': 'ericf129', 'link': '/bbs/movie/M.1563681507.A.57B.html'}
# {'title': '[公告] 板務宣導 2019/07', 'push': '1', 'date': '7/23', 'author': 'kai3368', 'link': '/bbs/movie/M.1563815831.A.1E8.html'}

# %%
widths = [
        (126,    1), (159,    0), (687,     1), (710,   0), (711,   1),
        (727,    0), (733,    1), (879,     0), (1154,  1), (1161,  0),
        (4347,   1), (4447,   2), (7467,    1), (7521,  0), (8369,  1),
        (8426,   0), (9000,   1), (9002,    2), (11021, 1), (12350, 2),
        (12351,  1), (12438,  2), (12442,   0), (19893, 2), (19967, 1),
        (55203,  2), (63743,  1), (64106,   2), (65039, 1), (65059, 0),
        (65131,  2), (65279,  1), (65376,   2), (65500, 1), (65510, 2),
        (120831, 1), (262141, 2), (1114109, 1),
]


def calc_len(string):
    def chr_width(o):
        global widths
        if o == 0xe or o == 0xf:
            return 0
        for num, wid in widths:
            if o <= num:
                return wid
        return 1
    return sum(chr_width(ord(c)) for c in string)


def pretty_print(push, title, date, author):
    pattern = '%3s\t%s%s%s\t%s'
    padding = ' ' * (50 - calc_len(title))
    print(pattern % (push, title, padding, date, author))

# %%
controls = html.find('.action-bar a.btn.wide')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2539227ae437> in <module>
# ----> 1 controls = html.find('.action-bar a.btn.wide')
#
# NameError: name 'html' is not defined

# %%
link = controls[1].get('href')
page_url = urllib.parse.urljoin('https://www.ptt.cc/', link)

# %%
def parse_article_meta(ent):
    ''' Step-3 (revised): parse the metadata in article entry '''
    # 基本要素都還在
    meta = {
        'title': ent.find('div.title', first=True).text,
        'push': ent.find('div.nrec', first=True).text,
        'date': ent.find('div.date', first=True).text,
    }

    try:
        # 正常狀況取得資料
        meta['author'] = ent.find('div.author', first=True).text
        meta['link'] = ent.find('div.title > a', first=True).attrs['href']
    except AttributeError:
        # 但碰上文章被刪除時，就沒有辦法像原本的方法取得 作者 跟 連結
        if '(本文已被刪除)' in meta['title']:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', meta['title'])
            if match_author:
                meta['author'] = match_author.group(1)
        elif re.search('已被\w*刪除', meta['title']):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', meta['title'])
            if match_author:
                meta['author'] = match_author.group(1)
    return meta

    # 最終仍回傳統一的 dict() 形式 paired data
    return meta

# %%
import urllib.parse
from imp import reload
import utils
reload(utils)
from utils import pretty_print

def get_metadata_from(url):

    def parse_next_link(doc):
        html = HTML(html=doc)
        controls = html.find('.action-bar a.btn.wide')
        link = controls[1].attrs.get('href')
        return urllib.parse.urljoin('https://www.ptt.cc/', link)

    resp = fetch(url)
    post_entries = parse_article_entries(resp.text)
    next_link = parse_next_link(resp.text)

    metadata = [parse_article_meta(entry) for entry in post_entries]
    return metadata, next_link

def get_paged_meta(url, num_pages):
    collected_meta = []

    for _ in range(num_pages):
        posts, link = get_metadata_from(url)
        collected_meta += posts
        url = urllib.parse.urljoin('https://www.ptt.cc/', link)

    return collected_meta

start_url = 'https://www.ptt.cc/bbs/movie/index.html'
metadata = get_paged_meta(start_url, num_pages=3)
for meta in metadata:
    pretty_print(meta['push'], meta['title'], meta['date'], meta['author'])

# %%
print(0xf)
# Out:
# 15

# %%
for meta in metadata:
    pretty_print(meta['title'], meta['date'], meta['author'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e417d42ebd1c> in <module>
# ----> 1 for meta in metadata:
#       2     pretty_print(meta['title'], meta['date'], meta['author'])
#
# NameError: name 'metadata' is not defined
