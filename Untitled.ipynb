# %%
import requests

def fetch(url):
    response = requests.get(url)
    response = requests.get(url, cookies={'over18': '1'})  # 一直向 server 回答滿 18 歲了 !
    return response

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
resp = fetch(url)  # step-1

print(resp.text) # result of setp-1
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index38912.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296129.A.108.html">Re: [爆卦]中國稅改徵全球稅 掀在陸工作、退休返台潮</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">yjjia</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E7%88%86%E5%8D%A6%5D%E4%B8%AD%E5%9C%8B%E7%A8%85%E6%94%B9%E5%BE%B5%E5%85%A8%E7%90%83%E7%A8%85&#43;%E6%8E%80%E5%9C%A8%E9%99%B8%E5%B7%A5%E4%BD%9C%E3%80%81%E9%80%80%E4%BC%91%E8%BF%94%E5%8F%B0%E6%BD%AE">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ayjjia">搜尋看板內 yjjia 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296138.A.943.html">[問卦] 寢室沒室友該怎麼辦？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">a210510</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%AF%A2%E5%AE%A4%E6%B2%92%E5%AE%A4%E5%8F%8B%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BE%A6%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aa210510">搜尋看板內 a210510 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296152.A.8C6.html">[問卦] 想吃火鍋卻吃膩平常吃的那些怎辦?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jkhz</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%83%B3%E5%90%83%E7%81%AB%E9%8D%8B%E5%8D%BB%E5%90%83%E8%86%A9%E5%B9%B3%E5%B8%B8%E5%90%83%E7%9A%84%E9%82%A3%E4%BA%9B%E6%80%8E%E8%BE%A6%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajkhz">搜尋看板內 jkhz 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296159.A.58B.html">[問卦] 統神張嘉航484又白回來了</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">std92050</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%B5%B1%E7%A5%9E%E5%BC%B5%E5%98%89%E8%88%AA484%E5%8F%88%E7%99%BD%E5%9B%9E%E4%BE%86%E4%BA%86">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Astd92050">搜尋看板內 std92050 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296161.A.B77.html">[問卦] 今天是證明棒球輸給了雨刷不是韓國嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">PoorHunter</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E4%BB%8A%E5%A4%A9%E6%98%AF%E8%AD%89%E6%98%8E%E6%A3%92%E7%90%83%E8%BC%B8%E7%B5%A6%E4%BA%86%E9%9B%A8%E5%88%B7%E4%B8%8D%E6%98%AF%E9%9F%93%E5%9C%8B%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3APoorHunter">搜尋看板內 PoorHunter 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">3</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296175.A.DAB.html">Re: [問卦] 贏韓國是不是年改的關係?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">mliao</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%B4%8F%E9%9F%93%E5%9C%8B%E6%98%AF%E4%B8%8D%E6%98%AF%E5%B9%B4%E6%94%B9%E7%9A%84%E9%97%9C%E4%BF%82%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Amliao">搜尋看板內 mliao 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296189.A.8EB.html">[問卦] 美國黑人484最終進化阿</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">a78914124</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%BE%8E%E5%9C%8B%E9%BB%91%E4%BA%BA484%E6%9C%80%E7%B5%82%E9%80%B2%E5%8C%96%E9%98%BF">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aa78914124">搜尋看板內 a78914124 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296204.A.AA0.html">Re: [問卦] 哆啦A夢他們到底重複一年幾次了啦?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">KDimitrov313</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%93%86%E5%95%A6A%E5%A4%A2%E4%BB%96%E5%80%91%E5%88%B0%E5%BA%95%E9%87%8D%E8%A4%87%E4%B8%80%E5%B9%B4%E5%B9%BE%E6%AC%A1%E4%BA%86%E5%95%A6%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKDimitrov313">搜尋看板內 KDimitrov313 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296279.A.F92.html">[問卦] 運動等於國力  所以台灣國力上升了吧??</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">proprome</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%81%8B%E5%8B%95%E7%AD%89%E6%96%BC%E5%9C%8B%E5%8A%9B&#43;&#43;%E6%89%80%E4%BB%A5%E5%8F%B0%E7%81%A3%E5%9C%8B%E5%8A%9B%E4%B8%8A%E5%8D%87%E4%BA%86%E5%90%A7%3F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aproprome">搜尋看板內 proprome 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296296.A.C38.html">[新聞] 最新民調：不畏對手烏賊戰！林佳龍選情</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">a3788466</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E6%9C%80%E6%96%B0%E6%B0%91%E8%AA%BF%EF%BC%9A%E4%B8%8D%E7%95%8F%E5%B0%8D%E6%89%8B%E7%83%8F%E8%B3%8A%E6%88%B0%EF%BC%81%E6%9E%97%E4%BD%B3%E9%BE%8D%E9%81%B8%E6%83%85">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aa3788466">搜尋看板內 a3788466 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296313.A.9D9.html">[新聞] 淹水災情慘！　徐國勇「沒有藥吃了不感冒</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ralfeistein</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E6%B7%B9%E6%B0%B4%E7%81%BD%E6%83%85%E6%85%98%EF%BC%81%E3%80%80%E5%BE%90%E5%9C%8B%E5%8B%87%E3%80%8C%E6%B2%92%E6%9C%89%E8%97%A5%E5%90%83%E4%BA%86%E4%B8%8D%E6%84%9F%E5%86%92">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aralfeistein">搜尋看板內 ralfeistein 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296348.A.3C1.html">[ＦＢ] 蠢羊與奇怪生物</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Birthday5566</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%EF%BC%A6%EF%BC%A2%5D&#43;%E8%A0%A2%E7%BE%8A%E8%88%87%E5%A5%87%E6%80%AA%E7%94%9F%E7%89%A9">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ABirthday5566">搜尋看板內 Birthday5566 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296368.A.77D.html">[問卦] 這次中華隊真的讓我太失望了</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">XXaa</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%80%99%E6%AC%A1%E4%B8%AD%E8%8F%AF%E9%9A%8A%E7%9C%9F%E7%9A%84%E8%AE%93%E6%88%91%E5%A4%AA%E5%A4%B1%E6%9C%9B%E4%BA%86">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AXXaa">搜尋看板內 XXaa 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535296370.A.D9C.html">[問卦] 業餘球隊大部分是什麼原因不打職棒？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">signm</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%A5%AD%E9%A4%98%E7%90%83%E9%9A%8A%E5%A4%A7%E9%83%A8%E5%88%86%E6%98%AF%E4%BB%80%E9%BA%BC%E5%8E%9F%E5%9B%A0%E4%B8%8D%E6%89%93%E8%81%B7%E6%A3%92%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Asignm">搜尋看板內 signm 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/26</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1510415718.A.D77.html">[公告] 八卦板板規(2017.11.11)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Kay731</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282017.11.11%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKay731">搜尋看板內 Kay731 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">94</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1533045631.A.0B6.html">[公告] 八月份置底閒聊文</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E6%9C%88%E4%BB%BD%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E6%96%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 7/31</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">11</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535205047.A.283.html">[協尋] 8/24清晨岡山嘉新東路行車記錄器</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">breadbear</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;8%2F24%E6%B8%85%E6%99%A8%E5%B2%A1%E5%B1%B1%E5%98%89%E6%96%B0%E6%9D%B1%E8%B7%AF%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Abreadbear">搜尋看板內 breadbear 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/25</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535038720.A.7AD.html">[協尋] 8/23朋友姨丈搭公車失蹤尋人</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">donghey</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;8%2F23%E6%9C%8B%E5%8F%8B%E5%A7%A8%E4%B8%88%E6%90%AD%E5%85%AC%E8%BB%8A%E5%A4%B1%E8%B9%A4%E5%B0%8B%E4%BA%BA">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Adonghey">搜尋看板內 donghey 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">16</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1535037865.A.D5D.html">[協尋] 8/23新北市新店區中興路一段93號</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jack455161</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;8%2F23%E6%96%B0%E5%8C%97%E5%B8%82%E6%96%B0%E5%BA%97%E5%8D%80%E4%B8%AD%E8%88%88%E8%B7%AF%E4%B8%80%E6%AE%B593%E8%99%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajack455161">搜尋看板內 jack455161 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 8/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %%
from requests_html import HTML

def parse_article_entries(doc):
    html = HTML(html=doc)
    post_entries = html.find('div.r-ent')
    return post_entries

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
resp = fetch(url)  # step-1
post_entries = parse_article_entries(resp.text)  # step-2

print(post_entries)  # result of setp-2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8f26c182e38f> in <module>()
# ----> 1 from requests_html import HTML
#       2
#       3 def parse_article_entries(doc):
#       4     html = HTML(html=doc)
#       5     post_entries = html.find('div.r-ent')
#
# ModuleNotFoundError: No module named 'requests_html'

# %%
from requests_html import HTMLSession
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0ccd03653a03> in <module>()
# ----> 1 from requests_html import HTMLSession
#
# ModuleNotFoundError: No module named 'requests_html'
